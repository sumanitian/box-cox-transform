# %% [markdown]
# # scipy.stats.boxcox
# Scipy has statistics toolbox / library.
#
# In statistics module, there is a function called boxcox. It takes an n-dimensional array ndarray
#
# scipy.stats.boxcox(x, λ) returns a boxcox power transformed array.

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
ax1 = plt.subplot(211)
x = stats.loggamma.rvs(5, size=500) + 5   # loggamma is one of the power law distributions
prob = stats.probplot(x, dist=stats.norm, plot=ax1) # probplot is Q-Q plot between X: loggamma & Y: normal 
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')
# Out:
# Text(0.5, 1.0, 'Probplot against normal distribution')

# %%
ax2 = plt.subplot(212)
xt, _ = stats.boxcox(x)   # xt is normally distributed. xt = boxcox(x)
prob = stats.probplot(xt, dist=stats.norm, plot = ax2) # probplot is a Q-Q plot between X: boxcox(X) = xt & Y: normal
ax2.set_xlabel('')
ax2.set_title('Probplot after Box-Cox transformation')
plt.show()

# %% [raw]
# Function boxcox in scipy.stats module gives us all the important information on converting a random variable X which is Power law / Pareto distributed to Y which is Gaussian / Normal distributed
